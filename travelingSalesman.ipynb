# %% [markdown]
# Renato Dias Ferreira Campos

# %% [markdown]
# <h1>Problema do Caixeiro Viajante</h1>

# %% [markdown]
# Suponha que um caixeiro viajante tenha que visitar \( n \) cidades diferentes, iniciando e encerrando sua viagem na **primeira cidade**. Suponha, também, que:
#
# 1. **A ordem das visitas não importa.**
# 2. De qualquer cidade, o caixeiro pode ir diretamente para qualquer outra.
#
# O objetivo do problema do Caixeiro Viajante é **descobrir a rota que minimiza a distância total da viagem**, considerando que o ponto de partida e o ponto final são a mesma cidade.

# %% [markdown]
# <h2/>Importando bibliotecas</h2>

# %%
import numpy as np
import random

# %% [markdown]
# ### Declarando número de cidades e gerando distâncias de maneira aleatória

# %%
#Número de cidades
n = 6

distancias = np.zeros((n, n), dtype = int)
for i in range(n):
  for j in range(i):
    distancias[i][j] = random.randint(1,100)
    distancias[j][i] = distancias[i][j]

print(distancias)
# Out:
# [[ 0 50 32 69 18 41]
#  [50  0 69 11 30 75]
#  [32 69  0 16 84 60]
#  [69 11 16  0 88 63]
#  [18 30 84 88  0 97]
#  [41 75 60 63 97  0]]

# %% [markdown]
# ### Inicialização dos indvíduos

# %%
#Escolhemos um número pequeno de indivíduos pois existem poucas combinações possíveis
#Dessa maneira, aumentamos as chances do caminho mais curto ainda não estar presente na nossa população inicial
#Garantindo que nosso algoritmo genético possa ser observado com resultados

num_individuos = 10
viagens = n + 1
populacao_inicial = np.zeros((num_individuos, viagens), dtype=int)

#Garantindo que a cidade 0 seja o início e fim da viagem
for i in range(num_individuos):
  populacao_inicial[i][0] = 0
  populacao_inicial[i][n] = 0

  populacao_inicial[i][1:n] = random.sample(range(1, n), n - 1)

for i in range(num_individuos):
  print(populacao_inicial[i])
# Out:
# [0 5 3 1 4 2 0]
# [0 1 4 3 2 5 0]
# [0 4 5 2 3 1 0]
# [0 3 1 5 2 4 0]
# [0 1 3 4 2 5 0]
# [0 4 3 5 2 1 0]
# [0 3 5 4 1 2 0]
# [0 2 1 3 5 4 0]
# [0 5 4 1 3 2 0]
# [0 3 5 2 1 4 0]

# %% [markdown]
# ### Definindo a função fitness
# Ela será calculada por meio da soma das distâncias, usando linha X coluna da matriz

# %%
def fitness(ind):

  f = 0

  #Soma das distâncias
  for i in range(1, len(ind)):
    f = f + distancias[ind[i-1]][ind[i]]

  return f


def retorna_fitness(populacao):

  fit = []

  #Criação da list de fitnesses
  for i in range(len(populacao)):
    f = fitness(populacao[i])
    fit.append(f)

  return fit

# %% [markdown]
# ### Seleção por torneio

# %%
def selecao_torneio(fitnesses):

    ind1 = -1
    ind2 = -1
    while ind1 == ind2:
        # Torneio 1
        sorteados = random.sample(range(0, len(fitnesses)), 2)
        if fitnesses[sorteados[0]] < fitnesses[sorteados[1]]:
            ind1 = sorteados[0]
        else:
            ind1 = sorteados[1]

        # Torneio 2
        sorteados = random.sample(range(0, len(fitnesses)), 2)
        if fitnesses[sorteados[0]] < fitnesses[sorteados[1]]:
            ind2 = sorteados[0]
        else:
            ind2 = sorteados[1]

    return ind1, ind2

# %% [markdown]
# ### Cruzamento Order Crossover
#
# Usado para garantir as regras das viagens, ou seja, deve-se passar por todas as cidades e não deve haver repetição.

# %%
def cruzamento(ids, populacao):
    pai1 = populacao[ids[0]]
    pai2 = populacao[ids[1]]

    #Criação dos pontos de começo e fim
    start, end = sorted(random.sample(range(1, len(pai1) - 1), 2))

    filho = [0] * len(pai1)
    #O filho recebe os elementos do pai1 de start até end
    filho[start:end] = pai1[start:end]

    pos = end
    #O filho recebe os elementos do pai2 que ainda não estão presentes em filho
    for gene in pai2[1:-1]:
        if gene not in filho:
            if pos >= len(pai1) - 1:
                pos = 1
            filho[pos] = gene
            pos += 1

    filho[0], filho[-1] = 0, 0
    return filho

# %% [markdown]
# ### Exemplificação do Cruzamento Order Crossover

# %%
pai_exemplo_1 = [0, 2, 1, 4, 5, 3, 0]
pai_exemplo_2 = [0, 2, 3, 1, 4, 5, 0]

start, end = sorted(random.sample(range(1, len(pai_exemplo_1) - 1), 2))

filho = [0] * len(pai_exemplo_1)
filho[start:end] = pai_exemplo_1[start:end]

print(f"Start: {start}\nEnd: {end}")
print(f"Pai1: {pai_exemplo_1}\nPai2: {pai_exemplo_2}")

pos = end
for gene in pai_exemplo_2[1:-1]:
    if gene not in filho:
        if pos >= len(pai_exemplo_1) - 1:
            pos = 1
        print(filho)
        filho[pos] = gene
        pos += 1

filho[0], filho[-1] = 0, 0

print(f"Filho: {filho}")
# Out:
# Start: 1
# End: 3
# Pai1: [0, 2, 1, 4, 5, 3, 0]
# Pai2: [0, 2, 3, 1, 4, 5, 0]
# [0, 2, 1, 0, 0, 0, 0]
# [0, 2, 1, 3, 0, 0, 0]
# [0, 2, 1, 3, 4, 0, 0]
# Filho: [0, 2, 1, 3, 4, 5, 0]

# %% [markdown]
# ### Elitismo

# %%
def elitismo(fitnesses):
    id_melhor = fitnesses.index(min(fitnesses))

    fitnesses.pop(id_melhor)
    id_melhor2 = fitnesses.index(min(fitnesses))

    return id_melhor, id_melhor2

# %% [markdown]
# ### Criação das Permutações
#
# Visto que temos 120 possibilidades de viagens, podemos enumerá-las e verificar a menor distância possível. Assim, podemos comparar com o resultado do nosso algoritmo genético

# %%
import itertools

cidades = [1, 2, 3, 4, 5]
permutacoes = list(itertools.permutations(cidades))

matriz = []

#Criação de todas as viagens
for p in permutacoes:
    p = [0] + list(p) + [0]
    matriz.append(list(p))

# %%
fitnesses = retorna_fitness(matriz)
i = 1

#Retorna todas as viagens posssíveis e suas respectivas distâncias
for viagem, distancia in zip(matriz, fitnesses):
    print(f"Viagem {i}: {viagem}: Distância: {distancia}")
    i += 1
# Out:
# Viagem 1: [0, 1, 2, 3, 4, 5, 0]: Distância: 361
# Viagem 2: [0, 1, 2, 3, 5, 4, 0]: Distância: 313
# Viagem 83: [0, 4, 2, 5, 1, 3, 0]: Distância: 317
# Viagem 84: [0, 4, 2, 5, 3, 1, 0]: Distância: 286
# Viagem 85: [0, 4, 3, 1, 2, 5, 0]: Distância: 287
# Viagem 86: [0, 4, 3, 1, 5, 2, 0]: Distância: 284
# Viagem 87: [0, 4, 3, 2, 1, 5, 0]: Distância: 307
# Viagem 88: [0, 4, 3, 2, 5, 1, 0]: Distância: 307
# Viagem 89: [0, 4, 3, 5, 1, 2, 0]: Distância: 345
# Viagem 90: [0, 4, 3, 5, 2, 1, 0]: Distância: 348
# Viagem 91: [0, 4, 5, 1, 2, 3, 0]: Distância: 344
# Viagem 92: [0, 4, 5, 1, 3, 2, 0]: Distância: 249
# Viagem 93: [0, 4, 5, 2, 1, 3, 0]: Distância: 324
# Viagem 94: [0, 4, 5, 2, 3, 1, 0]: Distância: 252
# Viagem 95: [0, 4, 5, 3, 1, 2, 0]: Distância: 290
# Viagem 96: [0, 4, 5, 3, 2, 1, 0]: Distância: 313
# Viagem 97: [0, 5, 1, 2, 3, 4, 0]: Distância: 307
# Viagem 98: [0, 5, 1, 2, 4, 3, 0]: Distância: 426
# Viagem 99: [0, 5, 1, 3, 2, 4, 0]: Distância: 245
# Viagem 100: [0, 5, 1, 3, 4, 2, 0]: Distância: 331
# Viagem 101: [0, 5, 1, 4, 2, 3, 0]: Distância: 315
# Viagem 102: [0, 5, 1, 4, 3, 2, 0]: Distância: 282
# Viagem 103: [0, 5, 2, 1, 3, 4, 0]: Distância: 287
# Viagem 104: [0, 5, 2, 1, 4, 3, 0]: Distância: 357
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]: Distância: 176
# Viagem 106: [0, 5, 2, 3, 4, 1, 0]: Distância: 285
# Viagem 107: [0, 5, 2, 4, 1, 3, 0]: Distância: 295
# Viagem 108: [0, 5, 2, 4, 3, 1, 0]: Distância: 334
# Viagem 109: [0, 5, 3, 1, 2, 4, 0]: Distância: 286
# Viagem 110: [0, 5, 3, 1, 4, 2, 0]: Distância: 261
# Viagem 111: [0, 5, 3, 2, 1, 4, 0]: Distância: 237
# Viagem 112: [0, 5, 3, 2, 4, 1, 0]: Distância: 284
# Viagem 113: [0, 5, 3, 4, 1, 2, 0]: Distância: 323
# Viagem 114: [0, 5, 3, 4, 2, 1, 0]: Distância: 395
# Viagem 115: [0, 5, 4, 1, 2, 3, 0]: Distância: 322
# Viagem 116: [0, 5, 4, 1, 3, 2, 0]: Distância: 227
# Viagem 117: [0, 5, 4, 2, 1, 3, 0]: Distância: 371
# Viagem 118: [0, 5, 4, 2, 3, 1, 0]: Distância: 299
# Viagem 119: [0, 5, 4, 3, 1, 2, 0]: Distância: 338
# Viagem 120: [0, 5, 4, 3, 2, 1, 0]: Distância: 361

# %%
# Encontrar a distância mínima
distancia_minima = min(fitnesses)

# Filtrar todas as rotas com a mesma distância mínima
viagens_minimas = []
for i, distancia in enumerate(fitnesses):
    if distancia == distancia_minima:
        viagens_minimas.append((i + 1, matriz[i]))

# Imprimir os resultados
print(f"Viagens com a menor distância ({distancia_minima}):")
for viagem in viagens_minimas:
    indice, rota = viagem
    print(f"Viagem {indice}: {rota}")
# Out:
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]

# %% [markdown]
# ### Mutação
#
# A mutação é feita invertendo a posição de um elemento de índice idx1 com um elemento de índice idx2.

# %%
def mutacao(filho, taxa):
    if random.random() < taxa:
        idx1, idx2 = random.sample(range(1, len(filho) - 1), 2)
        filho[idx1], filho[idx2] = filho[idx2], filho[idx1]
    return filho

# %% [markdown]
# ### Programa principal do Algoritmo Evolutivo

# %%
num_geracoes = 100
for it in range(num_geracoes):
    nova_populacao = np.zeros((num_individuos, viagens), dtype=int)

    # Fitness da população
    fit = retorna_fitness(populacao_inicial)

    # Melhor indivíduo
    id_melhor = fit.index(min(fit))
    print(f"Melhor rota da geração {it + 1}: {populacao_inicial[id_melhor]} com custo {fit[id_melhor]}")
    print(f"Viagens com a menor distância ({distancia_minima}):")
    for viagem in viagens_minimas:
        indice, rota = viagem
        print(f"Viagem {indice}: {rota}")
    print()

    # Elitismo
    elite = elitismo(fit)
    nova_populacao[0] = populacao_inicial[elite[0]]
    nova_populacao[1] = populacao_inicial[elite[1]]

    # Geração dos filhos
    num_filhos = 2
    while num_filhos < num_individuos:
        vencedores = selecao_torneio(fit)
        filho = cruzamento(vencedores, populacao_inicial)
        filho = mutacao(filho, 0.5)
        nova_populacao[num_filhos] = filho
        num_filhos += 1

    # Atualizar população
    populacao_inicial = nova_populacao.copy()
# Out:
# Melhor rota da geração 1: [0 5 4 1 3 2 0] com custo 227
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 2: [0 5 4 1 3 2 0] com custo 227
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 3: [0 5 4 1 3 2 0] com custo 227
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 4: [0 5 4 1 3 2 0] com custo 227
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 5: [0 5 4 1 3 2 0] com custo 227
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 6: [0 4 1 3 5 2 0] com custo 214
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 7: [0 4 1 3 5 2 0] com custo 214
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 8: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 9: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 10: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 11: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 12: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 13: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 14: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 15: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 16: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 17: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 18: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 19: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 20: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 21: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 22: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 23: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 24: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 25: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 26: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 27: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 28: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 29: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 30: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 31: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 32: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 33: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 34: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 35: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 36: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 37: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 38: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 39: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 40: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 41: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 42: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 43: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 44: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 45: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 46: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 47: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 48: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 49: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 50: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 51: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 52: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 53: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 54: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 55: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 56: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 57: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 58: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 59: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 60: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 61: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 62: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 63: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 64: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 65: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 66: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 67: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 68: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 69: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 70: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 71: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 72: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 73: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 74: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 75: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 76: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 77: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 78: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 79: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 80: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 81: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 82: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 83: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 84: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 85: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 86: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 87: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 88: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 89: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 90: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 91: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 92: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 93: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 94: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 95: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 96: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 97: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 98: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 99: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
#
# Melhor rota da geração 100: [0 4 1 3 2 5 0] com custo 176
# Viagens com a menor distância (176):
# Viagem 75: [0, 4, 1, 3, 2, 5, 0]
# Viagem 105: [0, 5, 2, 3, 1, 4, 0]
